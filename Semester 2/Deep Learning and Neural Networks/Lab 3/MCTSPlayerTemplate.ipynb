# %%
# %run GameInterface.ipynb

# %%
import math

"""
This class represents one node in the MCTS search tree.
Feel free to change the methods or fields in order to
better fit the MCTS implementation.
"""

class Node:
    
    def __init__(self):
        
        # parent and child nodes
        self.parent = parent
        self.children = []
        
        # visits and value information
        self.value = 0
        self.visits = 0
        
        # TODO node might need more fields

    # generate the children of this node.
    def expand_node(self):
        pass

    # update this node via backpropagation.
    def update(self, value):
        pass
    
    # return the UCB1 value of this node.
    def ucb1(self):
        pass
    
"""
This class contains the template for MCTSPlayer, which
chooses a move based on a Monte-Carlo Tree search using
UCB1.
"""
class MCTSPlayer(Player):
        
    def __init__(self, piece, rollouts=500, max_rollout=100):
        super(MCTSPlayer, self).__init__(piece)
        
        # max number and depth of rollouts
        self.rollouts = max(1, rollouts)
        self.max_rollout = max(1, max_rollout)
      
    def chooseMove(self, game):
        
        root_node  = Node()
        
        for i in range(self.rollouts):
            
            print("rollouts not implemented")
            
            # selection
            # use the UCB1 values to select a leaf node

            #expansion
            # expand the leaf node
            # select one of its new children if it has any

            # rollout
            # perform a rollout and evaluate the final state
            # use random moves for the rollout

            # backpropagate
            # propagate the evaluation value back to the root
            # node, updating values and visits.
            
        # select move
        # after the rollouts, select the child of the root
        # node that has the best value (not best UCB1!)
        
        # return the chosen move
        return None
